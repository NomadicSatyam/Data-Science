# %%
#import plotly.plotly as py

# %%
import chart_studio.plotly as py

# %%
import  chart_studio.plotly as py
import plotly.graph_objs as go

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data=dict(type='choropleth',location=['AZ','CA','NY'],locationmode='USA-states'
          ,colourscale='portland',text=['text1','text2','text3'],z=[1.0,2.0,3.0],colorbar={'title':'Colorbar Title Goes Here'})

# %%
data
# Out:
# {'type': 'choropleth',
#  'location': ['AZ', 'CA', 'NY'],
#  'locationmode': 'USA-states',
#  'colourscale': 'portland',
#  'text': ['text1', 'text2', 'text3'],
#  'z': [1.0, 2.0, 3.0],
#  'colorbar': {'title': 'Colorbar Title Goes Here'}}

# %%
#layout=dict(geo={'scope':usa'})

# %%
#layout = dict(geo=dict(scope='usa'))

# %%
import plotly.graph_objs as go

# %%
choromap=go.Figure(data=data,layout=layout)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-e9bcf2335ab4> in <module>
# ----> 1 choromap=go.Figure(data=data,layout=layout)
#
# D:\Install folder\lib\site-packages\plotly\graph_objs\_figure.py in __init__(self, data, layout, frames, skip_invalid, **kwargs)
#     626             is invalid AND skip_invalid is False
#     627         """
# --> 628         super(Figure, self).__init__(data, layout, frames, skip_invalid, **kwargs)
#     629
#     630     def add_area(
#
# D:\Install folder\lib\site-packages\plotly\basedatatypes.py in __init__(self, data, layout_plotly, frames, skip_invalid, **kwargs)
#     155
#     156         # ### Import traces ###
# --> 157         data = self._data_validator.validate_coerce(data, skip_invalid=skip_invalid)
#     158
#     159         # ### Save tuple of trace objects ###
#
# ...

# %%
choromap = go.Figure(data = [data],layout = layout)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-243104ae4228> in <module>
# ----> 1 choromap = go.Figure(data = [data],layout = layout)
#
# D:\Install folder\lib\site-packages\plotly\graph_objs\_figure.py in __init__(self, data, layout, frames, skip_invalid, **kwargs)
#     626             is invalid AND skip_invalid is False
#     627         """
# --> 628         super(Figure, self).__init__(data, layout, frames, skip_invalid, **kwargs)
#     629
#     630     def add_area(
#
# D:\Install folder\lib\site-packages\plotly\basedatatypes.py in __init__(self, data, layout_plotly, frames, skip_invalid, **kwargs)
#     155
#     156         # ### Import traces ###
# --> 157         data = self._data_validator.validate_coerce(data, skip_invalid=skip_invalid)
#     158
#     159         # ### Save tuple of trace objects ###
#
# ...

# %%
layout=dict(geo={'scope':'usa'})

# %%
choromap=go.Figure(data=[data],layout=layout)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-475970b10949> in <module>
# ----> 1 choromap=go.Figure(data=[data],layout=layout)
#
# D:\Install folder\lib\site-packages\plotly\graph_objs\_figure.py in __init__(self, data, layout, frames, skip_invalid, **kwargs)
#     626             is invalid AND skip_invalid is False
#     627         """
# --> 628         super(Figure, self).__init__(data, layout, frames, skip_invalid, **kwargs)
#     629
#     630     def add_area(
#
# D:\Install folder\lib\site-packages\plotly\basedatatypes.py in __init__(self, data, layout_plotly, frames, skip_invalid, **kwargs)
#     155
#     156         # ### Import traces ###
# --> 157         data = self._data_validator.validate_coerce(data, skip_invalid=skip_invalid)
#     158
#     159         # ### Save tuple of trace objects ###
#
# ...

# %%
iplot(choromap)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-758ce4708b28> in <module>
# ----> 1 iplot(choromap)
#
# NameError: name 'choromap' is not defined

# %%
plot(choromap)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-30bbcf924467> in <module>
# ----> 1 plot(choromap)
#
# NameError: name 'plot' is not defined

# %%
df=pd.read_csv('2011_US_AGRI_Exports')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-f2d0a9b9a9b9> in <module>
# ----> 1 df=pd.read_csv('2011_US_AGRI_Exports')
#
# NameError: name 'pd' is not defined

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
data=dict(type='choropleth',colorscale='YIOrRd',
         locations=df['code'],locationmode='USA-states',z=df['total exports',
         ,text=df['text'],maker=dict(line=dict(color='rgb(255,255,255)',width=2))
                                                            colorbar={'title:'Millions USD'})
# Out:
#   File "<ipython-input-55-df364997fe40>", line 3
#     ,text=df['text'],maker=dict(line=dict(color='rgb(255,255,255)',width=2))
#     ^
# SyntaxError: invalid syntax

# %%
layout = dict(title = '2011 US Agritulculture Exports by State',
              geo = dict(scope='usa',
                         showlakes = True,
                         lakecolor = 'rgb(85,173,240)')
             )

# %%
layout
# Out:
# {'title': '2011 US Agritulculture Exports by State',
#  'geo': {'scope': 'usa', 'showlakes': True, 'lakecolor': 'rgb(85,173,240)'}}

# %%
choromao2=go.Figure(data=[data],layout=layout)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-47a10def90cb> in <module>
# ----> 1 choromao2=go.Figure(data=[data],layout=layout)
#
# D:\Install folder\lib\site-packages\plotly\graph_objs\_figure.py in __init__(self, data, layout, frames, skip_invalid, **kwargs)
#     612             is invalid AND skip_invalid is False
#     613         """
# --> 614         super(Figure, self).__init__(data, layout, frames, skip_invalid, **kwargs)
#     615
#     616     def add_area(
#
# D:\Install folder\lib\site-packages\plotly\basedatatypes.py in __init__(self, data, layout_plotly, frames, skip_invalid, **kwargs)
#     155
#     156         # ### Import traces ###
# --> 157         data = self._data_validator.validate_coerce(data, skip_invalid=skip_invalid)
#     158
#     159         # ### Save tuple of trace objects ###
#
# ...

# %%
iplot(choromap2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-161357828452> in <module>
# ----> 1 iplot(choromap2)
#
# NameError: name 'choromap2' is not defined
